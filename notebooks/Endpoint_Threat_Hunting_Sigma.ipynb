# %% [markdown]
# ## Cell 1: Imports

# %% [markdown]
# Install the required libraries using the following command:
#
#
# !pip install -r requirements.txt

# %%
import json
import pandas as pd
import numpy as np

# %% [markdown]
# ## Cell 2: Prerequisites

# %%
df = pd.read_csv("EID1.csv")

# %% [markdown]
# ### Cell 3: Extract EID1 Fields from Message (If you're getting data from Elastic)

# %%
#df = data

def extract_fields(message):
    fields = {
        'Image': None,
        'OriginalFileName': None,
        'CommandLine': None,
        'CurrentDirectory': None,
        'User': None,
        'ParentImage': None,
        'ParentCommandLine': None
    }

    if isinstance(message, str):
        for line in message.split('\n'):
            if line.startswith('Image: '):
                fields['Image'] = line.split('Image: ')[1]
            elif line.startswith('OriginalFileName: '):
                fields['OriginalFileName'] = line.split('OriginalFileName: ')[1]
            elif line.startswith('CommandLine: '):
                fields['CommandLine'] = line.split('CommandLine: ')[1]
            elif line.startswith('CurrentDirectory: '):
                fields['CurrentDirectory'] = line.split('CurrentDirectory: ')[1]
            elif line.startswith('User: '):
                fields['User'] = line.split('User: ')[1]
            elif line.startswith('ParentImage: '):
                fields['ParentImage'] = line.split('ParentImage: ')[1]
            elif line.startswith('ParentCommandLine: '):
                fields['ParentCommandLine'] = line.split('ParentCommandLine: ')[1]

    return pd.Series(fields)

extracted_df = df['message'].apply(extract_fields)

df = pd.concat([df, extracted_df], axis=1)

df.drop(columns=['message'], inplace=True)

display(df)
# Out:
#                       computer_name  event_id  \
# 0     MY-CAL-WIN10.MY-CALdera.local         1
# 1     MY-CAL-WIN10.MY-CALdera.local         1
# 2     MY-CAL-WIN10.MY-CALdera.local         1
# 3     MY-CAL-WIN10.MY-CALdera.local         1
# 4     MY-CAL-WIN10.MY-CALdera.local         1
# ...                             ...       ...
# 7313  MY-CAL-WIN10.MY-CALdera.local         1
# 7314  MY-CAL-WIN10.MY-CALdera.local         1
# 7315  MY-CAL-WIN10.MY-CALdera.local         1
# 7316  MY-CAL-WIN10.MY-CALdera.local         1
# 7317  MY-CAL-WIN10.MY-CALdera.local         1
#
#                                                   Image  OriginalFileName  \
# 0     C:\Program Files (x86)\Microsoft\EdgeUpdate\Mi...  msedgeupdate.dll
# 1     C:\Windows\System32\WindowsPowerShell\v1.0\pow...    PowerShell.EXE
# 2     C:\Windows\Microsoft.NET\Framework64\v4.0.3031...           csc.exe
# 3     C:\Windows\Microsoft.NET\Framework64\v4.0.3031...        CVTRES.EXE
# 4     C:\Windows\System32\WindowsPowerShell\v1.0\pow...    PowerShell.EXE
# ...                                                 ...               ...
# 7313  C:\Program Files (x86)\Microsoft\Edge\Applicat...        msedge.exe
# 7314  C:\Program Files (x86)\Microsoft\Edge\Applicat...        msedge.exe
# 7315  C:\Program Files (x86)\Microsoft\Edge\Applicat...        msedge.exe
# 7316  C:\Program Files (x86)\Microsoft\Edge\Applicat...        msedge.exe
# 7317  C:\Program Files (x86)\Microsoft\Edge\Applicat...        msedge.exe
#
#                                             CommandLine  \
# 0     "C:\Program Files (x86)\Microsoft\EdgeUpdate\M...
# 1     "powershell.exe" & {Install-Module -Name Azure...
# 2     "C:\Windows\Microsoft.NET\Framework64\v4.0.303...
# 3     C:\Windows\Microsoft.NET\Framework64\v4.0.3031...
# 4     "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# ...                                                 ...
# 7313  "C:\Program Files (x86)\Microsoft\Edge\Applica...
# 7314  "C:\Program Files (x86)\Microsoft\Edge\Applica...
# 7315  "C:\Program Files (x86)\Microsoft\Edge\Applica...
# 7316  "C:\Program Files (x86)\Microsoft\Edge\Applica...
# 7317  "C:\Program Files (x86)\Microsoft\Edge\Applica...
#
#                                        CurrentDirectory  \
# 0     C:\Program Files (x86)\Microsoft\EdgeUpdate\1....
# 1             C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\
# 2            C:\Users\johnny.douche\AppData\Local\Temp\
# 3            C:\Users\johnny.douche\AppData\Local\Temp\
# 4            C:\Users\johnny.douche\AppData\Local\Temp\
# ...                                                 ...
# 7313  C:\Program Files (x86)\Microsoft\Edge\Applicat...
# 7314  C:\Program Files (x86)\Microsoft\Edge\Applicat...
# 7315  C:\Program Files (x86)\Microsoft\Edge\Applicat...
# 7316  C:\Program Files (x86)\Microsoft\Edge\Applicat...
# 7317  C:\Program Files (x86)\Microsoft\Edge\Applicat...
#
#                           User  \
# 0          NT AUTHORITY\SYSTEM
# 1     MY-CALDERA\johnny.douche
# 2     MY-CALDERA\johnny.douche
# 3     MY-CALDERA\johnny.douche
# 4     MY-CALDERA\johnny.douche
# ...                        ...
# 7313  MY-CALDERA\johnny.douche
# 7314  MY-CALDERA\johnny.douche
# 7315  MY-CALDERA\johnny.douche
# 7316  MY-CALDERA\johnny.douche
# 7317  MY-CALDERA\johnny.douche
#
#                                             ParentImage  \
# 0     C:\Program Files (x86)\Microsoft\EdgeUpdate\Mi...
# 1     C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 2     C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 3     C:\Windows\Microsoft.NET\Framework64\v4.0.3031...
# 4     C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# ...                                                 ...
# 7313  C:\Program Files (x86)\Microsoft\Edge\Applicat...
# 7314  C:\Program Files (x86)\Microsoft\Edge\Applicat...
# 7315  C:\Program Files (x86)\Microsoft\Edge\Applicat...
# 7316  C:\Program Files (x86)\Microsoft\Edge\Applicat...
# 7317  C:\Program Files (x86)\Microsoft\Edge\Applicat...
#
#                                       ParentCommandLine
# 0     "C:\Program Files (x86)\Microsoft\EdgeUpdate\M...
# 1     "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 2     "powershell.exe" & {Install-Module -Name Excha...
# 3     "C:\Windows\Microsoft.NET\Framework64\v4.0.303...
# 4     "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# ...                                                 ...
# 7313  "C:\Program Files (x86)\Microsoft\Edge\Applica...
# 7314  "C:\Program Files (x86)\Microsoft\Edge\Applica...
# 7315  "C:\Program Files (x86)\Microsoft\Edge\Applica...
# 7316  "C:\Program Files (x86)\Microsoft\Edge\Applica...
# 7317  "C:\Program Files (x86)\Microsoft\Edge\Applica...
#
# [7318 rows x 9 columns]

# %% [markdown]
# ### Cell 4: Extract EID3 Fields from Message (If you're getting data from Elastic)

# %%
def extract_fields(message):
    fields = {
        'Image': None,
        'SourceIp': None,
        'SourceHostname': None,
        'SourcePort': None,
        'User': None,
        'DestinationIp': None,
        'DestinationHostname': None,
        'DestinationPort': None
    }

    if isinstance(message, str):
        for line in message.split('\n'):
            if line.startswith('Image: '):
                fields['Image'] = line.split('Image: ')[1]
            elif line.startswith('SourceIp: '):
                fields['SourceIp'] = line.split('SourceIp: ')[1]
            elif line.startswith('SourceHostname: '):
                fields['SourceHostname'] = line.split('SourceHostname: ')[1]
            elif line.startswith('SourcePort: '):
                fields['SourcePort'] = line.split('SourcePort: ')[1]
            elif line.startswith('User: '):
                fields['User'] = line.split('User: ')[1]
            elif line.startswith('DestinationIp: '):
                fields['DestinationIp'] = line.split('DestinationIp: ')[1]
            elif line.startswith('DestinationHostname: '):
                fields['DestinationHostname'] = line.split('DestinationHostname: ')[1]
            elif line.startswith('DestinationPort: '):
                fields['DestinationPort'] = line.split('DestinationPort: ')[1]

    return pd.Series(fields)

extracted_df = df['message'].apply(extract_fields)

df = pd.concat([df, extracted_df], axis=1)

df.drop(columns=['message'], inplace=True)

display(df)

# %% [markdown]
# ### Cell 5: Extract EID11 Fields from Message (If you're getting data from Elastic)

# %%
def extract_fields(message):
    fields = {
        'Image': None,
        'TargetFilename': None,
        'User': None
    }

    if isinstance(message, str):
        for line in message.split('\n'):
            if line.startswith('Image: '):
                fields['Image'] = line.split('Image: ')[1]
            elif line.startswith('TargetFilename: '):
                fields['TargetFilename'] = line.split('TargetFilename: ')[1]
            elif line.startswith('User: '):
                fields['User'] = line.split('User: ')[1]

    return pd.Series(fields)

extracted_df = df['message'].apply(extract_fields)

df = pd.concat([df, extracted_df], axis=1)

df.drop(columns=['message'], inplace=True)

display(df)

# %% [markdown]
# ## Cell 6: Credential Dumping

# %%
# Define the lists
credential_dumping_cmd = ['crypto::certificates', 'kerberos::golden', 'kerberos::list', 'kerberos::ptt', 'lsadump::dcsync', 'lsadump::lsa', 'lsadump::sam', 'lsadump::secrets', 'mimidrv.sys', 'mimikatz', 'mimilib', 'sekurlsa::logonpasswords', 'token::elevate', 'token::list']

credential_dumping_cmds_combo = [
    ['procdump', '-ma'],
    ['rdrleakdiag.exe', 'fullmemdmp'],
    ['tttracer.exe', '-dumpfull']
]


# Check if any of the commands in credential_dumping_cmd exist
cmds_exist = df['CommandLine'].apply(lambda x: any(cmd in str(x) for cmd in credential_dumping_cmd) if x is not None else False)
#print(df[cmds_exist])


# Check if all elements of any combo exist in a row
def check_combos(command, combo_list):

    if command is None:
        return False
    command = str(command)

    for combo in combo_list:
        if all(keyword in command for keyword in combo):
            return True
    return False

combo_cmds_exist = df['CommandLine'].apply(lambda x: check_combos(x, credential_dumping_cmds_combo))


## print the alerts(if any)
display(df[cmds_exist])
#display(df[combo_cmds_exist])
# Out:
#                       computer_name  event_id  \
# 56    MY-CAL-WIN10.MY-CALdera.local         1
# 90    MY-CAL-WIN10.MY-CALdera.local         1
# 163   MY-CAL-WIN10.MY-CALdera.local         1
# 164   MY-CAL-WIN10.MY-CALdera.local         1
# 428   MY-CAL-WIN10.MY-CALdera.local         1
# 446   MY-CAL-WIN10.MY-CALdera.local         1
# 821   MY-CAL-WIN10.MY-CALdera.local         1
# 866   MY-CAL-WIN10.MY-CALdera.local         1
# 941   MY-CAL-WIN10.MY-CALdera.local         1
# 979   MY-CAL-WIN10.MY-CALdera.local         1
# 1004  MY-CAL-WIN10.MY-CALdera.local         1
# 1006  MY-CAL-WIN10.MY-CALdera.local         1
# 1093  MY-CAL-WIN10.MY-CALdera.local         1
# 1097  MY-CAL-WIN10.MY-CALdera.local         1
# 1295  MY-CAL-WIN10.MY-CALdera.local         1
# 1344  MY-CAL-WIN10.MY-CALdera.local         1
# 1460  MY-CAL-WIN10.MY-CALdera.local         1
# 2034  MY-CAL-WIN10.MY-CALdera.local         1
# 2973  MY-CAL-WIN10.MY-CALdera.local         1
# 3014  MY-CAL-WIN10.MY-CALdera.local         1
# 3253  MY-CAL-WIN10.MY-CALdera.local         1
# 4046  MY-CAL-WIN10.MY-CALdera.local         1
# 4047  MY-CAL-WIN10.MY-CALdera.local         1
# 4734  MY-CAL-WIN10.MY-CALdera.local         1
# 4903  MY-CAL-WIN10.MY-CALdera.local         1
# 5133  MY-CAL-WIN10.MY-CALdera.local         1
# 5134  MY-CAL-WIN10.MY-CALdera.local         1
#
#                                                   Image OriginalFileName  \
# 56    C:\Windows\System32\WindowsPowerShell\v1.0\pow...   PowerShell.EXE
# 90                          C:\Windows\System32\cmd.exe          Cmd.Exe
# 163   C:\Windows\System32\WindowsPowerShell\v1.0\pow...   PowerShell.EXE
# 164                         C:\Windows\System32\cmd.exe          Cmd.Exe
# 428                         C:\Windows\System32\cmd.exe          Cmd.Exe
# 446   C:\Windows\System32\WindowsPowerShell\v1.0\pow...   PowerShell.EXE
# 821   C:\Windows\System32\WindowsPowerShell\v1.0\pow...   PowerShell.EXE
# 866                         C:\Windows\System32\cmd.exe          Cmd.Exe
# 941   C:\Windows\System32\WindowsPowerShell\v1.0\pow...   PowerShell.EXE
# 979   C:\Windows\System32\WindowsPowerShell\v1.0\pow...   PowerShell.EXE
# 1004  C:\Windows\System32\WindowsPowerShell\v1.0\pow...   PowerShell.EXE
# 1006                        C:\Windows\System32\cmd.exe          Cmd.Exe
# 1093                        C:\Windows\System32\cmd.exe          Cmd.Exe
# 1097  C:\Windows\System32\WindowsPowerShell\v1.0\pow...   PowerShell.EXE
# 1295  C:\Windows\System32\WindowsPowerShell\v1.0\pow...   PowerShell.EXE
# 1344                        C:\Windows\System32\cmd.exe          Cmd.Exe
# 1460                        C:\Windows\System32\cmd.exe          Cmd.Exe
# 2034  C:\Windows\System32\WindowsPowerShell\v1.0\pow...   PowerShell.EXE
# 2973  C:\Windows\System32\WindowsPowerShell\v1.0\pow...   PowerShell.EXE
# 3014  C:\Windows\System32\WindowsPowerShell\v1.0\pow...   PowerShell.EXE
# 3253                        C:\Windows\System32\cmd.exe          Cmd.Exe
# 4046                        C:\Windows\System32\cmd.exe          Cmd.Exe
# 4047  C:\AtomicRedTeam\ExternalPayloads\mimikatz\x64...     mimikatz.exe
# 4734                        C:\Windows\System32\cmd.exe          Cmd.Exe
# 4903  C:\AtomicRedTeam\ExternalPayloads\mimikatz\x64...     mimikatz.exe
# 5133                        C:\Windows\System32\cmd.exe          Cmd.Exe
# 5134  C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\mimik...     mimikatz.exe
#
#                                             CommandLine  \
# 56    "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 90    "C:\Windows\system32\cmd.exe" /c echo %%tmp%%\...
# 163   "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 164   "C:\Windows\system32\cmd.exe" /c echo C:\Atomi...
# 428   "C:\Windows\system32\cmd.exe" /c echo %%tmp%%\...
# 446   "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 821   "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 866   "C:\Windows\system32\cmd.exe" /c echo %%tmp%%\...
# 941   "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 979   "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 1004  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 1006  "C:\Windows\system32\cmd.exe" /c echo C:\Atomi...
# 1093  "C:\Windows\system32\cmd.exe" /c echo C:\Atomi...
# 1097  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 1295  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 1344  "C:\Windows\system32\cmd.exe" /c echo C:\Atomi...
# 1460  "cmd.exe" /c "C:\AtomicRedTeam\atomics\..\Exte...
# 2034  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 2973  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 3014  "powershell.exe" & {$url='https://raw.githubus...
# 3253  "cmd.exe" /c "C:\AtomicRedTeam\atomics\..\Exte...
# 4046  "cmd.exe" /c C:\AtomicRedTeam\atomics\..\Exter...
# 4047  C:\AtomicRedTeam\atomics\..\ExternalPayloads\m...
# 4734  "C:\Windows\system32\cmd.exe" /c 'C:\AtomicRed...
# 4903  "C:\AtomicRedTeam\ExternalPayloads\mimikatz\x6...
# 5133  "cmd.exe" /c %%tmp%%\mimikatz\x64\mimikatz.exe...
# 5134  C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\mimik...
#
#                                 CurrentDirectory                      User  \
# 56     C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 90    C:\Users\johnny.douche\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 163    C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 164   C:\Users\johnny.douche\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 428   C:\Users\johnny.douche\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 446    C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 821    C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 866   C:\Users\johnny.douche\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 941    C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 979    C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 1004   C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 1006  C:\Users\johnny.douche\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 1093  C:\Users\johnny.douche\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 1097   C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 1295   C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 1344  C:\Users\johnny.douche\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 1460   C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 2034   C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 2973   C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 3014   C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 3253   C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 4046   C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 4047   C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 4734  C:\Users\johnny.douche\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 4903  C:\Users\johnny.douche\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 5133   C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 5134   C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
#
#                                             ParentImage  \
# 56    C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 90    C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 163   C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 164   C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 428   C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 446   C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 821   C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 866   C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 941   C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 979   C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 1004  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 1006  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 1093  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 1097  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 1295  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 1344  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 1460  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 2034  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 2973  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 3014  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 3253  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 4046  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 4047                        C:\Windows\System32\cmd.exe
# 4734  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 4903  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 5133  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 5134                        C:\Windows\System32\cmd.exe
#
#                                       ParentCommandLine
# 56    "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 90    "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 163   "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 164   "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 428   "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 446   "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 821   "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 866   "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 941   "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 979   "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 1004  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 1006  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 1093  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 1097  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 1295  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 1344  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 1460  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 2034  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 2973  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 3014  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 3253  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 4046  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 4047  "cmd.exe" /c C:\AtomicRedTeam\atomics\..\Exter...
# 4734  "powershell.exe" & {# starting fake DC server,...
# 4903  "powershell.exe" & {# starting fake DC server,...
# 5133  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 5134  "cmd.exe" /c %tmp%\mimikatz\x64\mimikatz.exe "...

# %% [markdown]
# ### Cell 7: Abusing Windows Telemetry For Persistence
# Windows telemetry makes use of the binary CompatTelRunner.exe to run a variety of commands and perform the actual telemetry collections. This binary was created to be easily extensible, and to that end, it relies on the registry to instruct on which commands to run. The problem is, it will run any arbitrary command without restriction of location or type.

# %%
import pandas as pd

# Load the data
df = pd.read_csv('EID1_extracted.csv')

# Apply filters
filtered_df = df[
    #(df['source_name'] == 'Microsoft-Windows-Sysmon') &
    (df['event_id'] == 1) &
    (
        df['CommandLine'].str.lower().str.contains('schtasks') |
        df['CommandLine'].str.lower().str.contains(r'\\application experience\\microsoft compatibility appraiser')
    ) &
    ~(
        df['User'].str.lower().str.contains('authori') |
        df['User'].str.lower().str.contains('autori')
    )
]

result_df = filtered_df[['computer_name', 'ParentImage', 'ParentCommandLine', 'Image', 'CommandLine', 'OriginalFileName', 'CurrentDirectory', 'User']]

display(result_df)
# Out:
#                       computer_name  \
# 24    MY-CAL-WIN10.my-caldera.local
# 220   MY-CAL-WIN10.my-caldera.local
# 221   MY-CAL-WIN10.my-caldera.local
# 225   MY-CAL-WIN10.my-caldera.local
# 226   MY-CAL-WIN10.my-caldera.local
# 227   MY-CAL-WIN10.my-caldera.local
# 1122  MY-CAL-WIN10.my-caldera.local
# 1150  MY-CAL-WIN10.my-caldera.local
# 1442  MY-CAL-WIN10.my-caldera.local
# 1443  MY-CAL-WIN10.my-caldera.local
# 1444  MY-CAL-WIN10.my-caldera.local
# 1455  MY-CAL-WIN10.my-caldera.local
# 1457  MY-CAL-WIN10.my-caldera.local
# 2068  MY-CAL-WIN10.my-caldera.local
# 2069  MY-CAL-WIN10.my-caldera.local
# 2070  MY-CAL-WIN10.my-caldera.local
# 2071  MY-CAL-WIN10.my-caldera.local
# 3005  MY-CAL-WIN10.my-caldera.local
# 3468  MY-CAL-WIN10.my-caldera.local
# 3469  MY-CAL-WIN10.my-caldera.local
# 3786  MY-CAL-WIN10.my-caldera.local
# 3956  MY-CAL-WIN10.my-caldera.local
# 4018  MY-CAL-WIN10.my-caldera.local
# 4278  MY-CAL-WIN10.my-caldera.local
# 4348  MY-CAL-WIN10.my-caldera.local
# 4349  MY-CAL-WIN10.my-caldera.local
#
#                                             ParentImage  \
# 24    C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\nskF1...
# 220                         C:\Windows\System32\cmd.exe
# 221                         C:\Windows\System32\cmd.exe
# 225   C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 226                         C:\Windows\System32\cmd.exe
# 227                         C:\Windows\System32\cmd.exe
# 1122               C:\Program Files\Npcap\Uninstall.exe
# 1150  C:\AtomicRedTeam\ExternalPayloads\npcap_instal...
# 1442  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 1443                        C:\Windows\System32\cmd.exe
# 1444                        C:\Windows\System32\cmd.exe
# 1455  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 1457                        C:\Windows\System32\cmd.exe
# 2068  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 2069                        C:\Windows\System32\cmd.exe
# 2070  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 2071                        C:\Windows\System32\cmd.exe
# 3005                        C:\Windows\System32\cmd.exe
# 3468                        C:\Windows\System32\cmd.exe
# 3469  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 3786                        C:\Windows\SysWOW64\cmd.exe
# 3956  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 4018  C:\Program Files (x86)\Microsoft Office\root\O...
# 4278                        C:\Windows\System32\cmd.exe
# 4348  C:\Windows\System32\WindowsPowerShell\v1.0\pow...
# 4349                        C:\Windows\System32\cmd.exe
#
#                                       ParentCommandLine  \
# 24    "C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\nskF...
# 220   "cmd.exe" /c schtasks /query /xml /tn "\Micros...
# 221   "cmd.exe" /c schtasks /query /xml /tn "\Micros...
# 225   "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 226   "cmd.exe" /c schtasks /query /xml /tn "\Micros...
# 227   "cmd.exe" /c schtasks /query /xml /tn "\Micros...
# 1122  "C:\Program Files\Npcap\uninstall.exe" /S /no_...
# 1150  "C:\AtomicRedTeam\ExternalPayloads\npcap_insta...
# 1442  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 1443  "cmd.exe" /c schtasks /create /ru system /sc d...
# 1444  "cmd.exe" /c schtasks /create /ru system /sc d...
# 1455  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 1457  "cmd.exe" /c reg add HKCU\SOFTWARE\ATOMIC-T105...
# 2068  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 2069  "cmd.exe" /c SCHTASKS /Create /SC ONCE /TN spa...
# 2070  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 2071  "cmd.exe" /c SCHTASKS /Create /S localhost /RU...
# 3005  "cmd.exe" /c schtasks /create /tn "T1053_005_O...
# 3468  "cmd.exe" /c schtasks /create /tn "T1053_005_O...
# 3469  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 3786  C:\Windows\SysWOW64\cmd.exe /c schtasks /creat...
# 3956  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 4018  "C:\Program Files (x86)\Microsoft Office\Root\...
# 4278  "cmd.exe" /c copy %temp%\ExplorerSync.db %temp...
# 4348  "C:\Windows\System32\WindowsPowerShell\v1.0\po...
# 4349  "cmd.exe" /c schtasks.exe /Change /TN "\Micros...
#
#                                  Image  \
# 24    C:\Windows\SysWOW64\schtasks.exe
# 220   C:\Windows\System32\schtasks.exe
# 221   C:\Windows\System32\schtasks.exe
# 225        C:\Windows\System32\cmd.exe
# 226   C:\Windows\System32\schtasks.exe
# 227   C:\Windows\System32\schtasks.exe
# 1122  C:\Windows\SysWOW64\schtasks.exe
# 1150  C:\Windows\SysWOW64\schtasks.exe
# 1442       C:\Windows\System32\cmd.exe
# 1443  C:\Windows\System32\schtasks.exe
# 1444  C:\Windows\System32\schtasks.exe
# 1455       C:\Windows\System32\cmd.exe
# 1457  C:\Windows\System32\schtasks.exe
# 2068       C:\Windows\System32\cmd.exe
# 2069  C:\Windows\System32\schtasks.exe
# 2070       C:\Windows\System32\cmd.exe
# 2071  C:\Windows\System32\schtasks.exe
# 3005  C:\Windows\System32\schtasks.exe
# 3468  C:\Windows\System32\schtasks.exe
# 3469       C:\Windows\System32\cmd.exe
# 3786  C:\Windows\SysWOW64\schtasks.exe
# 3956       C:\Windows\System32\cmd.exe
# 4018       C:\Windows\SysWOW64\cmd.exe
# 4278  C:\Windows\System32\schtasks.exe
# 4348       C:\Windows\System32\cmd.exe
# 4349  C:\Windows\System32\schtasks.exe
#
#                                             CommandLine OriginalFileName  \
# 24    SCHTASKS.EXE /Create /F /RU SYSTEM /SC ONSTART...     schtasks.exe
# 220   schtasks  /query /xml /tn "\Microsoft\Windows\...     schtasks.exe
# 221   schtasks  /query /xml /tn "\Microsoft\Windows\...     schtasks.exe
# 225   "cmd.exe" /c schtasks /query /xml /tn "\Micros...          Cmd.Exe
# 226   schtasks  /query /xml /tn "\Microsoft\Windows\...     schtasks.exe
# 227   schtasks  /query /xml /tn "\Microsoft\Windows\...     schtasks.exe
# 1122          SCHTASKS.EXE /Delete /F /TN npcapwatchdog     schtasks.exe
# 1150  SCHTASKS.EXE /Create /F /RU SYSTEM /SC ONSTART...     schtasks.exe
# 1442  "cmd.exe" /c schtasks /create /ru system /sc d...          Cmd.Exe
# 1443  schtasks  /create /ru system /sc daily /tr "cm...     schtasks.exe
# 1444                    schtasks  /query /tn win32times     schtasks.exe
# 1455  "cmd.exe" /c reg add HKCU\SOFTWARE\ATOMIC-T105...          Cmd.Exe
# 1457  schtasks.exe  /Create /F /TN "ATOMIC-T1053.005...     schtasks.exe
# 2068  "cmd.exe" /c SCHTASKS /Create /SC ONCE /TN spa...          Cmd.Exe
# 2069  SCHTASKS  /Create /SC ONCE /TN spawn /TR C:\wi...     schtasks.exe
# 2070  "cmd.exe" /c SCHTASKS /Create /S localhost /RU...          Cmd.Exe
# 2071  SCHTASKS  /Create /S localhost /RU DOMAIN\user...     schtasks.exe
# 3005  schtasks  /create /tn "T1053_005_OnStartup" /s...     schtasks.exe
# 3468  schtasks  /create /tn "T1053_005_OnLogon" /sc ...     schtasks.exe
# 3469  "cmd.exe" /c schtasks /create /tn "T1053_005_O...          Cmd.Exe
# 3786  schtasks  /create /tn "OpenCalcTask" /tr "C:\W...     schtasks.exe
# 3956  "cmd.exe" /c copy %%temp%%\ExplorerSync.db %%t...          Cmd.Exe
# 4018  C:\Windows\SysWOW64\cmd.exe /c schtasks /creat...          Cmd.Exe
# 4278  schtasks  /create /tn ExplorerSync /tr "javaw ...     schtasks.exe
# 4348  "cmd.exe" /c schtasks.exe /Change /TN "\Micros...          Cmd.Exe
# 4349  schtasks.exe  /Change /TN "\Microsoft\Windows\...     schtasks.exe
#
#                                CurrentDirectory                      User
# 24                      C:\Program Files\Npcap\  MY-CALDERA\johnny.douche
# 220   C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 221   C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 225   C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 226   C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 227   C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 1122                    C:\Program Files\Npcap\  MY-CALDERA\johnny.douche
# 1150                    C:\Program Files\Npcap\  MY-CALDERA\johnny.douche
# 1442  C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 1443  C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 1444  C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 1455  C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 1457  C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 2068  C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 2069  C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 2070  C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 2071  C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 3005  C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 3468  C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 3469  C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 3786                       C:\Windows\system32\  MY-CALDERA\johnny.douche
# 3956  C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 4018                       C:\Windows\system32\  MY-CALDERA\johnny.douche
# 4278  C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 4348  C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche
# 4349  C:\Users\JOHNNY~1.DOU\AppData\Local\Temp\  MY-CALDERA\johnny.douche

# %% [markdown]
# ## Cell 8: ID1 to Sigma Converter

# %%
import yaml

def sigma_to_python(sigma_rule_path, log_file='EID1_extracted.csv', output_file='generated_code.py'):
    # Load the Sigma rule from a YAML file
    with open(sigma_rule_path, 'r') as f:
        sigma_rule = yaml.safe_load(f)

    detection = sigma_rule.get('detection', {})
    conditions = detection.get('condition', '')

    # Start generating Python code
    python_code = f"""
import pandas as pd

# Load the logs from the CSV file
log_file = '{log_file}'
df = pd.read_csv(log_file)

# Applying Sigma Rule: {sigma_rule.get('title', 'Unnamed Rule')}
"""

    # Process selection criteria
    selections = {key: val for key, val in detection.items() if key.startswith('selection')}

    # Process each selection
    for key, value in selections.items():
        python_code += f"\n# Applying {key} conditions\n"
        for field, conditions in value.items():
            if isinstance(conditions, list):
                # Handles conditions with a list, such as endswith or contains
                if field.endswith('|endswith'):
                    field_name = field.replace('|endswith', '')
                    python_code += f"df = df[df['{field_name}'].str.endswith({conditions}, na=False)]\n"
                elif field.endswith('|contains'):
                    field_name = field.replace('|contains', '')
                    python_code += f"df = df[df['{field_name}'].str.contains('|'.join({conditions}), case=False, na=False)]\n"
            elif isinstance(conditions, dict):
                # Handles nested conditions like 'CommandLine|contains'
                for sub_field, sub_conditions in conditions.items():
                    if isinstance(sub_conditions, list):
                        python_code += f"df = df[df['{sub_field}'].str.contains('|'.join({sub_conditions}), case=False, na=False)]\n"

    # Final output for filtered data based on conditions
    python_code += """
# Display the suspicious activities
if not df.empty:
    print("Suspicious activities found:")
    print(df[['Image', 'OriginalFileName', 'CommandLine', 'UtcTime', 'UserName']])
else:
    print("No suspicious activities found.")
"""

    # Save the generated Python code into a file
    with open(output_file, 'w') as f:
        f.write(python_code)

    print(f"Python code saved to {output_file}")

# Example usage
sigma_rule_file = 'dotnet exec.yaml'
sigma_to_python(sigma_rule_file)
# Out:
# Python code saved to generated_code.py

# %% [markdown]
# ## Cell 9: EID3 to Sigma Converter

# %%
import pandas as pd
import yaml


def sigma_to_python(sigma_rule_path, log_file='EID3.csv', output_file='EID3 Detector.py'):
    # Load the Sigma rule from a YAML file
    with open(sigma_rule_path, 'r') as f:
        sigma_rule = yaml.safe_load(f)

    detection = sigma_rule.get('detection', {})

    # Start generating Python code
    python_code = f"""
import pandas as pd

# Load the logs from the CSV file
log_file = '{log_file}'
df = pd.read_csv(log_file)

# Applying Sigma Rule: {sigma_rule.get('title', 'Unnamed Rule')}
"""

    # Process selection criteria
    selection = detection.get('selection', {})
    filter_main_local_ip = detection.get('filter_main_local_ip', {})
    filter_main_msrange = detection.get('filter_main_msrange', {})

    # Apply selection conditions
    python_code += f"\n# Applying selection conditions\n"

    # Check for PowerShell or pwsh process in 'Image' column
    if 'Image|endswith' in selection:
        power_shell_processes = selection['Image|endswith']
        python_code += f"df = df[df['Image'].str.lower().str.endswith(tuple({power_shell_processes}), na=False)]\n"

    # Apply filter criteria to exclude local IP ranges (filter_main_local_ip)
    python_code += "\n# Exclude local IP ranges\n"
    if 'DestinationIp|cidr' in filter_main_local_ip:
        local_ip_ranges = filter_main_local_ip['DestinationIp|cidr']
        python_code += f"""
local_ip_ranges = {local_ip_ranges}
def ip_not_in_range(ip, ranges):
    from ipaddress import ip_network, ip_address
    for ip_range in ranges:
        if ip_address(ip) in ip_network(ip_range):
            return False
    return True

df['is_valid_ip'] = df['DestinationIp'].apply(lambda x: ip_not_in_range(x, local_ip_ranges))
df = df[df['is_valid_ip']]
"""

    # Apply filter for Microsoft IP ranges (filter_main_msrange)
    python_code += "\n# Exclude Microsoft IP ranges\n"
    if 'DestinationIp|cidr' in filter_main_msrange:
        ms_ip_ranges = filter_main_msrange['DestinationIp|cidr']
        python_code += f"""
ms_ip_ranges = {ms_ip_ranges}
df['is_valid_ip'] = df['DestinationIp'].apply(lambda x: ip_not_in_range(x, ms_ip_ranges))
df = df[df['is_valid_ip']]
"""

    # Exclude rows where the user contains certain keywords (like 'AUTHORI' or 'AUTORI')
    if 'User|contains' in filter_main_local_ip:
        excluded_users = filter_main_local_ip['User|contains']
        python_code += f"""
df = df[~df['User'].str.contains('|'.join({excluded_users}), case=False, na=False)]
"""

    # Final output for filtered data based on conditions
    python_code += """
# Display the suspicious activities
if not df.empty:
    print("Suspicious network connections initiated by PowerShell found:")
    print(df[['Image', 'SourceIp', 'SourceHostname', 'SourcePort', 'User', 'DestinationIp', 'DestinationHostname', 'DestinationPort']])
else:
    print("No suspicious activities found.")
"""

    # Save the generated Python code into a file
    with open(output_file, 'w') as f:
        f.write(python_code)

    print(f"Python code saved to {output_file}")

# Example usage
sigma_rule_file = 'powershell netconn.yaml'
sigma_to_python(sigma_rule_file)
# Out:
# Python code saved to EID3 Detector.py

# %% [markdown]
# ## Cell 10: Extras

# %%
import yaml

def sigma_to_python(sigma_rule_path, log_file='EID1_extracted.csv', output_file='generated_code88.py'):
    # Load the Sigma rule from a YAML file
    with open(sigma_rule_path, 'r') as f:
        sigma_rule = yaml.safe_load(f)

    detection = sigma_rule.get('detection', {})
    conditions = detection.get('condition', '')

    # Start generating Python code
    python_code = f"""
import pandas as pd

# Load the logs from the CSV file
log_file = '{log_file}'
df = pd.read_csv(log_file)

# Applying Sigma Rule: {sigma_rule.get('title', 'Unnamed Rule')}
"""

    # Process selection criteria
    selection = detection.get('selection', [])

    # Print the selection criteria for debugging
    print("Selection criteria:", selection)

    # Apply selection conditions
    python_code += f"\n# Applying selection conditions\n"

    # Loop through each condition in selection
    for condition in selection:
        if 'Image|endswith' in condition:
            jsc_process = condition['Image|endswith']
            python_code += f"df = df[df['Image'].str.lower().str.endswith('{jsc_process}', na=False)]\n"

        if 'OriginalFileName' in condition:
            original_file_name = condition['OriginalFileName']
            python_code += f"df = df[df['OriginalFileName'].str.lower() == '{original_file_name.lower()}']\n"

    # Final output for filtered data based on conditions
    python_code += """
# Display the suspicious activities
if not df.empty:
    print("Suspicious JScript Compiler (jsc.exe) execution found:")
    print(df[['Image', 'OriginalFileName', 'CommandLine', 'User']])
else:
    print("No suspicious activities found.")
"""

    # Save the generated Python code into a file
    with open(output_file, 'w') as f:
        f.write(python_code)

    print(f"Python code saved to {output_file}")

# Example usage
sigma_rule_file = 'jsc exec.yaml'
sigma_to_python(sigma_rule_file)
# Out:
# Selection criteria: [{'Image|endswith': '\\jsc.exe'}, {'OriginalFileName': 'jsc.exe'}]
# Python code saved to generated_code88.py

# %%
import yaml

def sigma_to_python(sigma_rule_path, log_file='EID1_extracted.csv', output_file='generated_code.py'):
    # Load the Sigma rule from a YAML file
    with open(sigma_rule_path, 'r') as f:
        sigma_rule = yaml.safe_load(f)

    detection = sigma_rule.get('detection', {})
    conditions = detection.get('condition', '')

    # Start generating Python code
    python_code = f"""
import pandas as pd

# Load the logs from the CSV file
log_file = '{log_file}'
df = pd.read_csv(log_file)

# Applying Sigma Rule: {sigma_rule.get('title', 'Unnamed Rule')}
"""

    # Process selection criteria
    selections = {key: val for key, val in detection.items() if key.startswith('selection')}

    # Process each selection
    for key, value in selections.items():
        python_code += f"\n# Applying {key} conditions\n"
        for field, condition in value.items():
            # Handle 'contains' conditions with lists
            if isinstance(condition, list) and field.endswith('|contains'):
                field_name = field.replace('|contains', '')
                # Escape backslashes properly in the condition list
                condition_escaped = [cond.replace("\\", "\\\\") for cond in condition]
                python_code += f"df = df[df['{field_name}'].str.contains('|'.join({condition_escaped}), case=False, na=False)]\n"
            # Handle 'endswith' conditions
            elif field.endswith('|endswith'):
                field_name = field.replace('|endswith', '')
                # Escape backslashes properly
                condition_escaped = condition.replace("\\", "\\\\")
                python_code += f"df = df[df['{field_name}'].str.endswith(r'{condition_escaped}', na=False)]\n"
            # Handle 'contains|all' conditions
            elif field.endswith('|contains|all') and isinstance(condition, list):
                field_name = field.replace('|contains|all', '')
                # Escape backslashes in each condition and concatenate with logical AND
                condition_escaped = [cond.replace("\\", "\\\\") for cond in condition]
                conditions_str = " & ".join([f"df['{field_name}'].str.contains(r'{val}', case=False, na=False)" for val in condition_escaped])
                python_code += f"df = df[{conditions_str}]\n"

    # Handle condition logic like '1 of selection_*'
    if 'condition' in detection:
        condition = detection['condition']
        if '1 of selection_' in condition:
            python_code += f"\n# Applying condition: {condition}\n"
            python_code += "df_filtered = pd.concat([\n"
            for key in selections.keys():
                python_code += f"    df,  # Filtered {key} condition\n"
            python_code += "]).drop_duplicates()\n"
            python_code += "df = df_filtered\n"

    # Final output for filtered data based on conditions
    python_code += """
# Display the suspicious activities
if not df.empty:
    print("Suspicious activities found:")
    print(df[['Image', 'CommandLine', 'Hashes', 'UtcTime', 'UserName']])
else:
    print("No suspicious activities found.")
"""

    # Save the generated Python code into a file
    with open(output_file, 'w') as f:
        f.write(python_code)

    print(f"Python code saved to {output_file}")

# Example usage
sigma_rule_file = 'forest_blizzard_sigma.yaml'
sigma_to_python(sigma_rule_file)
# Out:
# Python code saved to generated_code.py

# %%
import yaml

def sigma_to_python(sigma_rule_path, log_file='EID1_extracted.csv', output_file='generated_code.py'):
    # Load the Sigma rule from a YAML file
    with open(sigma_rule_path, 'r') as f:
        sigma_rule = yaml.safe_load(f)

    detection = sigma_rule.get('detection', {})
    conditions = detection.get('condition', '')

    # Start generating Python code
    python_code = f"""
import pandas as pd

# Load the logs from the CSV file
log_file = '{log_file}'
df = pd.read_csv(log_file)

# Applying Sigma Rule: {sigma_rule.get('title', 'Unnamed Rule')}
"""

    # Process selection criteria
    selections = {key: val for key, val in detection.items() if key.startswith('selection')}

    # Process each selection
    for key, value in selections.items():
        python_code += f"\n# Applying {key} conditions\n"

        # Check if value is a list (in your case, 'selection' is a list of dictionaries)
        if isinstance(value, list):
            for condition in value:
                for field, condition_value in condition.items():
                    # Handle 'endswith' conditions
                    if field.endswith('|endswith'):
                        field_name = field.replace('|endswith', '')
                        condition_escaped = condition_value.replace("\\", "\\\\")
                        python_code += f"df = df[df['{field_name}'].str.endswith(r'{condition_escaped}', na=False)]\n"
                    # Handle exact match conditions
                    elif isinstance(condition_value, str):
                        condition_escaped = condition_value.replace("\\", "\\\\")
                        python_code += f"df = df[df['{field}'].str.lower() == '{condition_escaped.lower()}']\n"
        else:
            # Handle the case where the value is a dictionary
            for field, condition_value in value.items():
                # Handle 'contains' conditions with lists
                if isinstance(condition_value, list) and field.endswith('|contains'):
                    field_name = field.replace('|contains', '')
                    condition_escaped = [cond.replace("\\", "\\\\") for cond in condition_value]
                    python_code += f"df = df[df['{field_name}'].str.contains('|'.join({condition_escaped}), case=False, na=False)]\n"

                # Handle 'endswith' conditions
                elif field.endswith('|endswith'):
                    field_name = field.replace('|endswith', '')
                    condition_escaped = condition_value.replace("\\", "\\\\")
                    python_code += f"df = df[df['{field_name}'].str.endswith(r'{condition_escaped}', na=False)]\n"

                # Handle 'contains|all' conditions
                elif field.endswith('|contains|all') and isinstance(condition_value, list):
                    field_name = field.replace('|contains|all', '')
                    condition_escaped = [cond.replace("\\", "\\\\") for cond in condition_value]
                    conditions_str = " & ".join([f"df['{field_name}'].str.contains(r'{val}', case=False, na=False)" for val in condition_escaped])
                    python_code += f"df = df[{conditions_str}]\n"

                # Handle exact match conditions
                elif isinstance(condition_value, str):
                    condition_escaped = condition_value.replace("\\", "\\\\")
                    python_code += f"df = df[df['{field}'].str.lower() == '{condition_escaped.lower()}']\n"

    # Handle condition logic (like '1 of selection_*' or boolean combinations)
    if 'condition' in detection:
        condition = detection['condition']
        if '1 of selection_' in condition:
            python_code += f"\n# Applying condition: {condition}\n"
            python_code += "df_filtered = pd.concat([\n"
            for key in selections.keys():
                python_code += f"    df[df[{key}]],\n"
            python_code += "]).drop_duplicates()\n"
            python_code += "df = df_filtered\n"
        else:
            # Implement more complex conditions if necessary
            python_code += f"\n# Applying complex condition logic: {condition}\n"

    # Final output for filtered data based on conditions
    python_code += """
# Display the suspicious activities
if not df.empty:
    print("Suspicious activities found:")
    print(df[['Image', 'CommandLine', 'Hashes', 'UtcTime', 'User']])
else:
    print("No suspicious activities found.")
"""

    # Save the generated Python code into a file
    with open(output_file, 'w') as f:
        f.write(python_code)

    print(f"Python code saved to {output_file}")

# Example usage
sigma_rule_file = 'forest_blizzard_sigma.yaml'
sigma_to_python(sigma_rule_file)
# Out:
# Python code saved to generated_code.py

# %% [markdown]
# ## References

# %% [markdown]
# - https://github.com/SigmaHQ/sigma
